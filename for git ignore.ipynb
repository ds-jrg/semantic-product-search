# %%
# !pwd
# !ls -la
# !git rev-parse --show-toplevel 2>/dev/null || echo "Not a git repo here"
# Out:
# /home/ringwald/paper
# total 148
# drwxr-xr-x 10 ringwald ringwald  4096 Oct 31 01:00  .
# drwxr-x--- 21 ringwald ringwald  4096 Oct 28 13:20  ..
# -rw-r--r--  1 ringwald ringwald   900 Oct 29 22:19  batch_tester.py
# -rw-r--r--  1 ringwald ringwald 63211 Oct 28 13:21  Benchmarks.ipynb
# drwxr-xr-x  3 ringwald ringwald  4096 Oct 28 13:22  data
# -rw-r--r--  1 ringwald ringwald  4336 Oct 31 01:00 'for git ignore.ipynb'
# -rw-r--r--  1 ringwald ringwald 21692 Oct 31 00:43  general_setup.py
# drwxr-xr-x  4 ringwald ringwald  4096 Oct 31 00:56  graph_creation
# drwxr-xr-x  2 ringwald ringwald  4096 Oct 31 01:00  .ipynb_checkpoints
# drwxr-xr-x  4 ringwald ringwald  4096 Oct 29 01:20  loss_fncs
# drwxr-xr-x  2 ringwald ringwald  4096 Oct 29 01:22  outputs
# drwxr-xr-x  6 ringwald ringwald  4096 Oct 28 17:14  pvenv
# -rw-r--r--  1 ringwald ringwald   102 Oct 28 17:12  requirements.txt
# drwxr-xr-x  4 ringwald ringwald  4096 Oct 29 22:20  scripts
# ...

# %%
# %%bash
# cat > .gitignore <<'EOF'
# # Python / Jupyter
# # no pycache
# __pycache__/
# *.py[cod]
# *.so
# *pt
# *pkl
#
# # Jupyter Notebook checkpoints
# .ipynb_checkpoints/
#
# pvenv/
# checkpoints/
# data/
# graph-data/
# gtpyg/
# model_save/
# models/
# temp_storage/
#
# *.pyc
# *.pyo
# *.pyd
#
# # Jupyter notebooks
# .ipynb_checkpoints/
# *.ipynb
#
# # Logs & outputs
# *.log
# *.out
# *.txt
# *.png
# *.jpg
# *.jpeg
# *.gif
# *.csv
#
#
# # System
# .DS_Store
#
# EOF
